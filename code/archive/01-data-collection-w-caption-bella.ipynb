# %% [markdown]
# # IMT 547 Project Part I: Data Collection

# %% [markdown]
# Chesie Yu

# %% [markdown]
# 02/17/2024

# %% [markdown]
# <style type = "text/css">
#     body {
#         font-family: "Serif";
#         font-size: 12pt;
#     }
#     em {
#         color: #4E7F9E;
#     }
#     strong {
#         color: #436D87;
#     }
#     li {
#         color: #4E7F9E;
#     }
#     ul {
#         color: #4E7F9E;
#     }
#     img {
#         display: block;
#         margin: auto;
#     }
#     .jp-RenderedHTMLCommon a:link {
#         color: #94C1C9;
#     }
#     .jp-RenderedHTMLCommon a:visited {
#         color: #94C1C9;
#     }
#     .jp-RenderedHTMLCommon code {
#         color: #4E7F9E;
#     }
#     .mark {
#         color: #B00D00;
#         background-color: #FFF7B1;
#     }
# </style>

# %% [markdown]
# _This notebook outlines the **data collection** process for the **YouTube Gaming Comment Toxicity** project._
#
# **Components**
# 1. **Authentication & Configuration**: Library setup, logging configuration, and API client initialization.
# 2. **Utility Functions**: A series of functions designed to streamline the data collection workflow.
# 3. **Data Collection**: Channel- and keyword-based data collection producing a DataFrame containing video and comment data.
#
# **Functions**
# - **`get_uploads_id(channel_id)`**: Fetch the uploads playlist ID for a given YouTube channel.
# - **`get_video_ids(uploads_id, max_videos=30, keywords=“”)`**: Fetch video IDs (default up to 30) based on given keywords from a upload playlist.
# - **`get_video_info(video_ids)`**: Fetch video info from a list of YouTube videos.
# - **`get_video_comments(video_ids, max_comments=100)`**: Fetch comment info (default up to 100) for a list of YouTube videos.
# - **`get_youtube_data(channel_ids, max_videos=30, max_comments=100, keywords=“”)`**: Main function. Fetch videos and comments for a list of channels.

# %% [markdown]
# **Data Collection Procedures**
#
# _To support our examination of the impact of game genres on comment toxicity across YouTube gaming channels, we have devised the following data collection approach:_
#
# 1. **Keyword Selection**: To **differentiate** action and non-action gaming videos on YouTube, we identified **two sets of keywords** representing popular games in each category.
#
#     The keyword sets are as follows:
#     **Action Games**: {"call of duty", "gta", "the last of us", "god of war", "batman", "red dead redemption", "assassin's creed", "star wars jedi", "resident evil", "cyberpunk", "fallout", "tomb raider", "elden ring"}
#     **Non-Action Games**: {"minecraft", "pokemon go", "just dance", "it takes two", "uncharted", "brawl stars"}
#
#
# 2. **Channel Selection**: From [SocialBook's Top 100 Gaming YouTubers](https://socialbook.io/youtube-channel-rank/top-100-gaming-youtubers), we curated a list of **33 channels** that predominantly create content in **English**.  For each channel, we **manually assigned** the binary labels `english` and `gamer` in `gamer-100.csv`, ensuring our focus on **English-speaking gaming community**.
#
#
# 3. **Data Collection**: Leveraging the **[YouTube Data API](https://developers.google.com/youtube/v3/getting-started)**, we gathered data from **30 videos per category for each channel**, using pre-defined keywords for action and non-action games.  We then collected the **100 most relevant top-level comments for each video**.
#
#     The sets of features include:
#     **Comment Features**: `“video_id”, “comment_id”, “comment_author_id”, “comment_text”, “comment_time”, “comment_likecount”, "comment_replycount"`
#     **Video Features**: `“channel_id”, “channel_name”, “video_id”, “video_title”, “video_creation_time”, “video_description”, “video_tags”, “video_viewcount”, “video_likecount”, "video_commentcount"`
#
# _The final dataset consists of **140,637 comments** encompassing **17 video and comment features**.  Through analyzing this data, we aim to uncover insights into the dynamics of toxic commenting behaviors within the YouTube gaming communities.  `02-preprocessing.ipynb` will focus on **data cleaning, text preprocessing, and feature labeling** for subsequent analysis._

# %% [markdown]
# ## 1. Authentication & Configuration

# %%
# The YouTube API key
# API_KEY = "AIzaSyAZoK_8LGGGeTh21WBqDxa94zUztIPGwQM"
API_KEY = "AIzaSyA_28SsnEgcSf6wckJM46pR_ZK05A1XzT8"

# %%
# Install libraries
# !pip install --upgrade google-api-python-client --quiet
# !pip install -U yt-dlp
# Out:
# Requirement already satisfied: yt-dlp in /Users/weiyue/anaconda3/lib/python3.11/site-packages (2023.12.30)
# Requirement already satisfied: mutagen in /Users/weiyue/anaconda3/lib/python3.11/site-packages (from yt-dlp) (1.47.0)
# Requirement already satisfied: pycryptodomex in /Users/weiyue/anaconda3/lib/python3.11/site-packages (from yt-dlp) (3.20.0)
# Requirement already satisfied: certifi in /Users/weiyue/anaconda3/lib/python3.11/site-packages (from yt-dlp) (2023.7.22)
# Requirement already satisfied: requests<3,>=2.31.0 in /Users/weiyue/anaconda3/lib/python3.11/site-packages (from yt-dlp) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.26.17 in /Users/weiyue/anaconda3/lib/python3.11/site-packages (from yt-dlp) (2.2.1)
# Requirement already satisfied: websockets>=12.0 in /Users/weiyue/anaconda3/lib/python3.11/site-packages (from yt-dlp) (12.0)
# Requirement already satisfied: brotli in /Users/weiyue/anaconda3/lib/python3.11/site-packages (from yt-dlp) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/weiyue/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.31.0->yt-dlp) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/weiyue/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.31.0->yt-dlp) (3.4)

# %%
# Import libraries
import json
import logging
import time
import pandas as pd
import googleapiclient
from pathlib import Path
from googleapiclient import discovery, errors

# %%
Path("../logs").mkdir(parents=True, exist_ok=True)
# Configure logging to file
logging.basicConfig(
    filename="../logs/data.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="w"
)

# %%
# Initialize the YouTube API
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=API_KEY)

# %% [markdown]
# <br>

# %% [markdown]
# ## 2. Utility Functions

# %%
def get_uploads_id(channel_id):
    """
    Fetch the uploads playlist ID for a given YouTube channel. 
    """
    # Call the API to find uploads channel id
    # Documentation: https://developers.google.com/youtube/v3/docs/channels/list
    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )
    res = request.execute()

    # Extract the uploads playlist id
    uploads_id = res["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
    
    return uploads_id

# %%
def get_video_ids(uploads_id, max_videos=30, keywords=""):
    """
    Fetch video IDs from a YouTube playlist.
    """
    # Empty list to store video_ids
    video_ids = []
    page_token = None
    
    # Loop until we collect enough videos
    while len(video_ids) < max_videos: 
        # Call the API to extract video IDs from playlist
        # Documentation: https://developers.google.com/youtube/v3/docs/playlistItems
        request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_id,
            pageToken=page_token,
            maxResults=50
        )
        res = request.execute()
    
        # Store the video ids
        for v in res["items"]: 
            # Check if title contains keywords
            # Maybe try stemming/lemmatization if I have the time?
            title = v["snippet"]["title"].lower()
            if any(k.lower() in title for k in keywords):
                video_ids.append(v["snippet"]["resourceId"]["videoId"])

            # Exit the loop once the required number of videos is reached
            if len(video_ids) >= max_videos:
                break 
    
        # Set the token
        page_token = res.get("nextPageToken")

        # Exit the loop if no token is found
        if not page_token: 
            break
    
    return video_ids

# %%
def get_video_info(video_ids):
    """
    Fetch video info from a list of YouTube videos.
    """
    # Empty list to store video info
    video_info = []

    for vid in video_ids:
        # Call the API to extract video info from ids
        # Documentation: https://developers.google.com/youtube/v3/docs/videos#resource
        request = youtube.videos().list(
            part="snippet, statistics",
            id=vid
        )
        res = request.execute()
        
        for v in res["items"]:
            # Extract relevant video info
            video_info.append({
                "channel_id": v["snippet"]["channelId"],
                "channel_name": v["snippet"]["channelTitle"],
                "video_id": v["id"],
                "video_title": v["snippet"]["title"],
                "video_creation_time": v["snippet"]["publishedAt"],
                "video_description": v["snippet"]["description"],
                "video_tags": v["snippet"].get("tags", []), 
                "video_viewcount": v["statistics"].get("viewCount", "0"),
                "video_likecount": v["statistics"].get("likeCount", "0"),
                "video_commentcount": v["statistics"].get("commentCount", "0"),
            })

    return video_info

# %%
def get_video_comments(video_ids, max_comments=100):
    """
    Fetch comments (up to max_comments) for a list of videos.
    """
    # Empty list to store the comments
    comment_info = []

    # Loop through the video ids
    for vid in video_ids:
        page_token = None 
        
        # Empty list to store individual video comments
        video_comment_info = []
        
        while len(video_comment_info) < max_comments:
            try:
                # Call the API to extract comments for videos
                # Documentation: https://developers.google.com/youtube/v3/docs/commentThreads/list
                request = youtube.commentThreads().list(
                    videoId=vid,
                    part="id, snippet, replies",
                    textFormat="plainText",
                    order="relevance",
                    maxResults=100,
                    pageToken=page_token
                )
                res = request.execute()

                # Extract relevant comment info
                for c in res["items"]:
                    video_comment_info.append({
                        "video_id": c["snippet"]["videoId"],
                        "comment_id": c["snippet"]["topLevelComment"]["id"],
                        "comment_author_id": c["snippet"]["topLevelComment"]["snippet"]["authorChannelId"]["value"],
                        "comment_text": c["snippet"]["topLevelComment"]["snippet"]["textOriginal"],
                        "comment_time": c["snippet"]["topLevelComment"]["snippet"]["updatedAt"],
                        "comment_likecount": c["snippet"]["topLevelComment"]["snippet"]["likeCount"],
                        "comment_replycount": c["snippet"]["totalReplyCount"]
                    })
                    
                    # Exit the loop once the required number of comments is reached
                    if len(video_comment_info) >= max_comments:
                        break

                # Set the token
                page_token = res.get("nextPageToken")

                # Exit the loop if no token is found
                if not page_token: 
                    break

            # Error handling for commentsDisabled
            except errors.HttpError as e:
                if e.resp.status == 403 and "commentsDisabled" in str(e):
                    logging.warning(f"Comments are disabled for video {vid}.")
                else:
                    logging.warning(f"An error occurred for video {vid}: {e}")
                break 
    
        # Extend the comment info
        comment_info.extend(video_comment_info)
    
    return comment_info

# %%
import traceback
import os
from pathlib import Path

def download_caption_for_video(video_id, caption_folder="captions"):
    """
    Download caption for a video with given video_id.
    """
    video_url = f"https://www.youtube.com/watch?v={video_id}"
    
    # Run the command to download the caption into given file
    os.system(f'yt-dlp --skip-download --write-auto-subs --write-subs --sub-lang en -o "{caption_folder}/{video_id}.%(ext)s" "https://www.youtube.com/watch?v={video_id}"')
    
    caption_file_list = list(Path(f"{caption_folder}").glob(f"{video_id}*"))
    caption_file_path = str(caption_file_list[0]) if len(caption_file_list) > 0 else ""
    return caption_file_path
    

def get_video_captions(video_ids, caption_folder="captions"):
    """
    Fetch captions for a list of videos.
    """
    # Empty list to store the comments
    captions_info = []

    # Loop through the video ids
    for vid in video_ids:
        page_token = None 
        
        # Empty list to store individual video captions
        video_caption_info = []
        
        try:
            # Call the API to extract captions for videos
            # Documentation: https://developers.google.com/youtube/v3/docs/captions/list
            request = youtube.captions().list(
                videoId=vid,
                part="id, snippet"
            )
            res = request.execute()

            # Extract relevant caption info
            for c in res["items"]:
                """ It is not working to download captions through youtube API because it only allows channel owner to do that.
                caption_download_request = youtube.captions().download(
                    id=c["id"]
                )
                print(c["id"])
                caption_download_result = caption_download_request.execute()
                print(caption_download_result)
                caption_content = caption_download_result
                """
                downloaded_caption_filepath = download_caption_for_video(vid, caption_folder=caption_folder)
                video_caption_info.append({
                    "video_id": c["snippet"]["videoId"],
                    "caption_id": c["id"],
                    "caption_time": c["snippet"]["lastUpdated"],
                    "caption_language": c["snippet"]["language"],
                    "caption_track_kind": c["snippet"]["trackKind"],
                    "caption_name": c["snippet"]["name"],
                    "caption_audio_track_type": c["snippet"]["audioTrackType"],
                    # "caption_content": caption_content,
                    "caption_file": downloaded_caption_filepath
                })

        # Error handling for commentsDisabled
        except errors.HttpError as e:
            logging.warning(f"An error occurred for video {vid}: {e}")
            traceback.print_exc()
            break 
    
        # Extend the comment info
        captions_info.extend(video_caption_info)
    
    return captions_info

# %%
video_ids = ["KeeeLsAa30M"]
caption_folder = "captions"
# Create the folder used to store the captions
Path(caption_folder).mkdir(parents=True, exist_ok=True)
# Get the video captions for a list of video ids
results = get_video_captions(video_ids, caption_folder=caption_folder)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KeeeLsAa30M
# [youtube] KeeeLsAa30M: Downloading webpage
# [youtube] KeeeLsAa30M: Downloading ios player API JSON
# [youtube] KeeeLsAa30M: Downloading android player API JSON
# [youtube] KeeeLsAa30M: Downloading m3u8 information
# [info] KeeeLsAa30M: Downloading subtitles: en
# [info] KeeeLsAa30M: Downloading 1 format(s): 22
# Deleting existing file captions/KeeeLsAa30M.en.vtt
# [info] Writing video subtitles to: captions/KeeeLsAa30M.en.vtt
# [download] Destination: captions/KeeeLsAa30M.en.vtt
# [download] 100% of  163.28KiB in 00:00:00 at 4.06MiB/s

# %%
results
# Out:
# [{'video_id': 'KeeeLsAa30M',
#   'caption_id': 'AUieDab6pGELWPUir3mOKynZhWh0bn0Wb95F2M_sWN_K1SQlAvk',
#   'caption_time': '2023-01-14T04:08:26.940662Z',
#   'caption_language': 'en',
#   'caption_track_kind': 'asr',
#   'caption_name': '',
#   'caption_audio_track_type': 'unknown',
#   'caption_file': 'captions/KeeeLsAa30M.en.vtt'}]

# %%
import re

def parse_caption_sentence(content):
    """
    Paser a single line of caption by removing some tags from it.
    """
    content = re.sub(r"\<c\>", "", content)
    content = re.sub(r"\</c\>", "", content)
    content = re.sub(r"\<\d\d\:\d\d:\d\d\.\d\d\d\>", "", content)
    content = " ".join([_.strip() for _ in content.split(" ")])
    return content
    

def parse_caption_from_file(file_path):
    """
    Parse the captions from the given file path and store it into a list
    """
    caption_list = []
    def add_current_caption(current_content_list, current_time_stamp):
        joined_content = "\n".join(current_content_list)
        if len(joined_content.strip()) == 0:
            pass
        elif len(caption_list) > 0 and caption_list[-1]["content"] in joined_content:
            # There is a duplicate, use the latest one to replace the previous one
            caption_list[-1]["content"] = joined_content
            caption_list[-1]["timestamp"] = current_time_stamp
        else:
            caption_list.append({
                "timestamp": current_time_stamp,
                "content": joined_content
            })
    with open(file_path) as f_in:
        current_time_stamp = None
        current_content_list = []
        for line in f_in:
            if re.match(r"^\d\d\:\d\d:\d\d\.\d\d\d", line):
                if current_time_stamp is not None:
                    add_current_caption(current_content_list, current_time_stamp)
                current_time_stamp = line.strip()
                current_content_list = []
            elif re.search(r"\<\d\d\:\d\d:\d\d\.\d\d\d\>", line):
                # Ignore some duplicate lines with timestamp inserted
                continue
            else:
                # parsed_content = parse_caption_sentence(line.strip())
                parsed_content = line.strip()
                if len(parsed_content) > 0:
                    current_content_list.append(parsed_content)
        if current_time_stamp is not None:
            add_current_caption(current_content_list, current_time_stamp)
    return caption_list

# %%
content_with_timestamp = parse_caption_from_file(results[0]["caption_file"])
content = "\n".join([_["content"] for _ in content_with_timestamp])

# %%
content
# Out:
# "dang do you have 39 million dollars\nlaying around you know I do well I know\nwhere you should spend it at a penthouse\na New York wow let's check this baby out\nit's gorgeous\n[Music]\nit looks like a psychiatric rooms are\njust pure white and you don't know where\nthe wolves are yeah I feel like I've\nstuck my toe on the edge of that sink\nevery time I walk through to the tub\nyeah\nyeah\nI don't know if you saw a few frames\nback but like the rooftop had a good\nview of some scaffolding yeah what a\nnice view good old scaffolding everyone\nthis I'm number one scaffolder hater\nhere in Japan they covered it up\nsee-through thing oh yeah that would be\nnice that would be nice they even have a\ndecibel meter at some uh like bigger\nconstructions to show like oh we're not\nmaking noise oh you can annoys pollution\nbut they have the meter there where it's\nlike\nall right well let's check out this\nwonderful investment\nat 39 looks amazing so far welcome to 11\nEast 68th Street on the Upper East Side\nin Manhattan this Penthouse has over 6\n200 square feet and 26. is that big can\nI don't know American thing 1600 square\nfeet yeah yeah it's pretty big all right\nso good investment after all yeah like\nlike a good sized family house would be\nprobably around like 2 000 or 1 800\nsquare feet so this thing's like pretty\nbig they covered everything with stone\nhuh out of those chairs I thought they\nwere TVs\nthey look so uncomfortable how do you\nsay on that it's got to be soft is that\nis it a chair yes chairs they just\ndescribed it and went\nI want to try the chair you're right\nactually yeah so the location here could\nnot be better she's like Scandinavian\nstep from Center Park Madison Avenue\nI would pay 39 million dollars do not\nlive in New York I was wondering what's\nNew York they're like oh I love it it's\nso wonderful I'm like have you been in\nit what what have you actually lived\nthere before I don't see what other\npeople see but I am willing to admit\nmaybe that has some charm so this pantas\nhas five bedrooms she said Panthers\nshe's definitely Scandinavian four\nfireplaces three Terraces and of course\nmy favorite the beautiful outdoor\nbarbecue kitchen all this that's pretty\ngood yours for 39 million dollars yeah\nbuys these I don't know I guess you're\npaying for all the stone yeah everything\nis just massive blocks of stone\neverywhere\neverywhere\nnice full bar with ice maker one\nrefrigerator and it's clad in this very\nbeautiful Onyx the Onyx is also backlit\nwith lighting so in the evening this\nreally stands out I think it's gonna go\nno I'm glowing I want to Glow in marble\nthing Onyx Onyx some Marvel notes Onyx\nI'm already saying that I would love to\nsay that even though it's ugly as\nhow thin does it have to be to let the\nlight Even Shine through yeah right that\ncan I see where the money went three\nstory staircase that is clad and marble\nit is surprise more stoned again yeah\nwe're still this is like the coldest\nhouse that's why they have five\nfireplaces because this place is\nfreezing\nfreezing\nbut they're not even fireplaces they're\nlike those electronic ones no yeah yeah\nyeah there's a gas I don't know we also\nhave a very unique feature within oh\nit's got an outdoor fireplace\nso you're outside entertaining you can\nlook at your fire and you're\nentertaining inside you will see it too\nthat's actually kind of cool I want to\ndouble-sided fireplace I want a 360\nfireplace 360.\nI was just thinking about how everything\nis Stone I wonder if like your feet hurt\nwalk around this house just because like\nwe have like hardwood floor or whatever\nthey usually have like a little pad on\nthe bottom of them to make it uh like a\nshock absorbent a little bit bottom\nfloor Old Stone I hate it like on my\nfeet am I just older Maybe\ndo you love it uh what's alone she's so\nI mean it's just a big block but I'm not\nthe the freaking green thing she's\ntalking about looks like it needs to be\ntrimme ...

# %% [markdown]
# ### Main Function

# %%
def get_youtube_data(channel_ids, max_videos=30, max_comments=100, keywords=""):
    """
    Fetch videos and comments for a list of channels
    """
    # Start timing
    start_time = time.time()
    
    all_video_info = []
    all_comment_info = []
    all_caption_info = []

    for channel_name, channel_id in channel_ids_dict.items():
        logging.info(f"Processing channel: {channel_name}")
        
        # Get uploads playlist id for channel
        uploads_id = get_uploads_id(channel_id)

        # Get video ids from uploads playlist
        video_ids = get_video_ids(uploads_id, max_videos, keywords)

        # Get video info from videos ids
        video_info = get_video_info(video_ids)
        all_video_info.extend(video_info)
        logging.info(f"Number of Videos Extracted: {len(video_info)}")
        
        # Fetch captions for each video
        caption_info = get_video_captions(video_ids)
        all_caption_info.extend(caption_info)
        logging.info(f"Number of Captions Extracted: {len(caption_info)}\n")

        # Fetch comments for each video
        comment_info = get_video_comments(video_ids, max_comments)
        all_comment_info.extend(comment_info)
        logging.info(f"Number of Comments Extracted: {len(comment_info)}\n")
    
    # Convert to DataFrames
    video_info_df = pd.DataFrame(all_video_info)
    comment_info_df = pd.DataFrame(all_comment_info)
    caption_info_df = pd.DataFrame(all_caption_info)

    # Merge video information with comments
    yt_comments = pd.merge(video_info_df, comment_info_df, on="video_id", how="inner")
    yt_comments = pd.merge(yt_comments, caption_info_df, on="video_id", how="inner")

    # End timing 
    print(f"Runtime: {time.time() - start_time:.4f} seconds")
    
    return yt_comments

# %% [markdown]
# <br>

# %% [markdown]
# ## 3. Data Collection

# %%
# Set the parameters
max_videos = 30
max_comments = 100

# Select the keywords
action_keywords = [
    "call of duty", "gta", "the last of us", "god of war", "batman", 
    "red dead redemption", "assassin's creed", "star wars jedi", 
    "resident evil", "cyberpunk", "fallout", "tomb raider", "elden ring"
]

nonaction_keywords = [
    "minecraft", "pokemon go", "just dance", "it takes two", "uncharted",
    "brawl stars"
]

# %%
# Load the data
channels = pd.read_csv("../data/gamer-100.csv")
channels.head()
# Out:
#        channel                channel_id  english  gamer  influence_score  \
# 0    PewDiePie  UC-lHJZR3Gqxm24_Vd_AJ5Yw      1.0      1               88
# 1           A4  UC2tsySbe9TNrI-xh2lximHA      0.0      1               61
# 2  JuegaGerman  UCYiGq8XF7YQD00x7wAd62Zg      0.0      1               82
# 3    Mikecrack  UCqJ5zFEED1hWs0KNQCQuYdQ      0.0      1               59
# 4   Fernanfloo  UCV4xOVpbcV8SdueDCOxLXtQ      0.0      1               82
#
#   followers avg_views posts eng_rate_60_day new_video_avg_views total_views  \
# 0    111.0m      7.6m  4.8k           2.80%                2.6m       29.2b
# 1     51.3m     20.8m   868          21.90%               10.1m       26.6b
# 2     49.3m      5.3m  2.1k           3.00%                1.1m       15.1b
# 3     47.7m      9.3m  2.0k           5.10%                2.1m       17.8b
# 4     46.9m     30.8m   544           4.00%                   0       10.5b
#
#        country
# 0        Japan
# 1      Belarus
# 2        Chile
# 3        Spain
# 4  El Salvador

# %%
# Filter the English-speaking gamer channels
filtered_channels = channels[(channels["english"] == 1) & (channels["gamer"] == 1)]

# Select the channels
channel_ids_dict = pd.Series(filtered_channels["channel_id"].values, 
                             index=filtered_channels["channel"]).to_dict()
len(channel_ids_dict)
# Out:
# 33

# %% [markdown]
# ### Action Gaming Videos

# %%
# Get YouTube videos and comments for action videos
yt_action = get_youtube_data(channel_ids_dict, max_videos, max_comments, action_keywords)
yt_action["genre"] = "action"
yt_action.head(3)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=F-yEoHL7MYY
# [youtube] F-yEoHL7MYY: Downloading webpage
# [youtube] F-yEoHL7MYY: Downloading ios player API JSON
# [youtube] F-yEoHL7MYY: Downloading android player API JSON
# [youtube] F-yEoHL7MYY: Downloading m3u8 information
# [info] F-yEoHL7MYY: Downloading subtitles: en
# [info] F-yEoHL7MYY: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/F-yEoHL7MYY.en.vtt
# [download] Destination: captions/F-yEoHL7MYY.en.vtt
# [download] 100% of  422.26KiB in 00:00:00 at 6.13MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PV4NGwn_xdI
# [youtube] PV4NGwn_xdI: Downloading webpage
# [youtube] PV4NGwn_xdI: Downloading ios player API JSON
# [youtube] PV4NGwn_xdI: Downloading android player API JSON
# [youtube] PV4NGwn_xdI: Downloading m3u8 information
# [info] PV4NGwn_xdI: Downloading subtitles: en
# [info] PV4NGwn_xdI: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/PV4NGwn_xdI.en.vtt
# [download] Destination: captions/PV4NGwn_xdI.en.vtt
# [download] 100% of   81.03KiB in 00:00:00 at 3.02MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CF3jK8ai0l4
# [youtube] CF3jK8ai0l4: Downloading webpage
# [youtube] CF3jK8ai0l4: Downloading ios player API JSON
# [youtube] CF3jK8ai0l4: Downloading android player API JSON
# [youtube] CF3jK8ai0l4: Downloading m3u8 information
# [info] CF3jK8ai0l4: Downloading subtitles: en
# [info] CF3jK8ai0l4: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/CF3jK8ai0l4.en.vtt
# [download] Destination: captions/CF3jK8ai0l4.en.vtt
# [download] 100% of   64.11KiB in 00:00:00 at 2.44MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Nr0h7H-EOmU
# [youtube] Nr0h7H-EOmU: Downloading webpage
# [youtube] Nr0h7H-EOmU: Downloading ios player API JSON
# [youtube] Nr0h7H-EOmU: Downloading android player API JSON
# [youtube] Nr0h7H-EOmU: Downloading m3u8 information
# [info] Nr0h7H-EOmU: Downloading subtitles: en
# [info] Nr0h7H-EOmU: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/Nr0h7H-EOmU.en.vtt
# [download] Destination: captions/Nr0h7H-EOmU.en.vtt
# [download] 100% of  560.82KiB in 00:00:00 at 6.04MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Os5abttbQrg
# [youtube] Os5abttbQrg: Downloading webpage
# [youtube] Os5abttbQrg: Downloading ios player API JSON
# [youtube] Os5abttbQrg: Downloading android player API JSON
# [youtube] Os5abttbQrg: Downloading m3u8 information
# [info] Os5abttbQrg: Downloading subtitles: en
# [info] Os5abttbQrg: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/Os5abttbQrg.en.vtt
# [download] Destination: captions/Os5abttbQrg.en.vtt
# [download] 100% of  512.18KiB in 00:00:00 at 5.37MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tC6WieI9rjg
# [youtube] tC6WieI9rjg: Downloading webpage
# [youtube] tC6WieI9rjg: Downloading ios player API JSON
# [youtube] tC6WieI9rjg: Downloading android player API JSON
# [youtube] tC6WieI9rjg: Downloading m3u8 information
# [info] tC6WieI9rjg: Downloading subtitles: en
# [info] tC6WieI9rjg: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/tC6WieI9rjg.en.vtt
# [download] Destination: captions/tC6WieI9rjg.en.vtt
# [download] 100% of  431.33KiB in 00:00:00 at 4.91MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zXcs6HqVOU8
# [youtube] zXcs6HqVOU8: Downloading webpage
# [youtube] zXcs6HqVOU8: Downloading ios player API JSON
# [youtube] zXcs6HqVOU8: Downloading android player API JSON
# [youtube] zXcs6HqVOU8: Downloading m3u8 information
# [info] zXcs6HqVOU8: Downloading subtitles: en
# [info] zXcs6HqVOU8: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/zXcs6HqVOU8.en.vtt
# [download] Destination: captions/zXcs6HqVOU8.en.vtt
# [download] 100% of  418.65KiB in 00:00:00 at 5.60MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Voi5IHNxkHQ
# [youtube] Voi5IHNxkHQ: Downloading webpage
# [youtube] Voi5IHNxkHQ: Downloading ios player API JSON
# [youtube] Voi5IHNxkHQ: Downloading android player API JSON
# [youtube] Voi5IHNxkHQ: Downloading m3u8 information
# [info] Voi5IHNxkHQ: Downloading subtitles: en
# [info] Voi5IHNxkHQ: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/Voi5IHNxkHQ.en.vtt
# [download] Destination: captions/Voi5IHNxkHQ.en.vtt
# [download] 100% of  462.61KiB in 00:00:00 at 5.67MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dgw9o2a39Q0
# [youtube] dgw9o2a39Q0: Downloading webpage
# [youtube] dgw9o2a39Q0: Downloading ios player API JSON
# [youtube] dgw9o2a39Q0: Downloading tv embedded player API JSON
# [youtube] dgw9o2a39Q0: Downloading android player API JSON
# [youtube] dgw9o2a39Q0: Downloading android embedded player API JSON
# [youtube] dgw9o2a39Q0: Downloading web embedded client config
# [youtube] dgw9o2a39Q0: Downloading player 3ffefd71
# [youtube] dgw9o2a39Q0: Downloading web embedded player API JSON
# [info] dgw9o2a39Q0: Downloading subtitles: en
# [info] dgw9o2a39Q0: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/dgw9o2a39Q0.en.vtt
# [download] Destination: captions/dgw9o2a39Q0.en.vtt
# [download] 100% of  507.42KiB in 00:00:00 at 5.84MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Dy3ege2nD6M
# [youtube] Dy3ege2nD6M: Downloading webpage
# [youtube] Dy3ege2nD6M: Downloading ios player API JSON
# [youtube] Dy3ege2nD6M: Downloading android player API JSON
# [youtube] Dy3ege2nD6M: Downloading m3u8 information
# [info] Dy3ege2nD6M: Downloading subtitles: en
# [info] Dy3ege2nD6M: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/Dy3ege2nD6M.en.vtt
# [download] Destination: captions/Dy3ege2nD6M.en.vtt
# [download] 100% of  641.72KiB in 00:00:00 at 5.64MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iROAUHfCrnU
# [youtube] iROAUHfCrnU: Downloading webpage
# [youtube] iROAUHfCrnU: Downloading ios player API JSON
# [youtube] iROAUHfCrnU: Downloading android player API JSON
# [youtube] iROAUHfCrnU: Downloading m3u8 information
# [info] iROAUHfCrnU: Downloading subtitles: en
# [info] iROAUHfCrnU: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/iROAUHfCrnU.en.vtt
# [download] Destination: captions/iROAUHfCrnU.en.vtt
# [download] 100% of  633.41KiB in 00:00:00 at 5.96MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zQNPaRcvivg
# [youtube] zQNPaRcvivg: Downloading webpage
# [youtube] zQNPaRcvivg: Downloading ios player API JSON
# [youtube] zQNPaRcvivg: Downloading android player API JSON
# [youtube] zQNPaRcvivg: Downloading m3u8 information
# [info] zQNPaRcvivg: Downloading subtitles: en
# [info] zQNPaRcvivg: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/zQNPaRcvivg.en.vtt
# [download] Destination: captions/zQNPaRcvivg.en.vtt
# [download] 100% of  578.43KiB in 00:00:00 at 3.90MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=I0JOvzYg4zI
# [youtube] I0JOvzYg4zI: Downloading webpage
# [youtube] I0JOvzYg4zI: Downloading ios player API JSON
# [youtube] I0JOvzYg4zI: Downloading android player API JSON
# [youtube] I0JOvzYg4zI: Downloading m3u8 information
# [info] I0JOvzYg4zI: Downloading subtitles: en
# [info] I0JOvzYg4zI: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/I0JOvzYg4zI.en.vtt
# [download] Destination: captions/I0JOvzYg4zI.en.vtt
# [download] 100% of  772.03KiB in 00:00:00 at 6.18MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1shCmkA9y7s
# [youtube] 1shCmkA9y7s: Downloading webpage
# [youtube] 1shCmkA9y7s: Downloading ios player API JSON
# [youtube] 1shCmkA9y7s: Downloading android player API JSON
# [youtube] 1shCmkA9y7s: Downloading m3u8 information
# [info] 1shCmkA9y7s: Downloading subtitles: en
# [info] 1shCmkA9y7s: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/1shCmkA9y7s.en.vtt
# [download] Destination: captions/1shCmkA9y7s.en.vtt
# [download] 100% of  511.91KiB in 00:00:00 at 5.46MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZNdPHViu96E
# [youtube] ZNdPHViu96E: Downloading webpage
# [youtube] ZNdPHViu96E: Downloading ios player API JSON
# [youtube] ZNdPHViu96E: Downloading android player API JSON
# [youtube] ZNdPHViu96E: Downloading m3u8 information
# [info] ZNdPHViu96E: Downloading subtitles: en
# [info] ZNdPHViu96E: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/ZNdPHViu96E.en.vtt
# [download] Destination: captions/ZNdPHViu96E.en.vtt
# [download] 100% of  639.07KiB in 00:00:00 at 5.90MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6yXKqV1JdgA
# [youtube] 6yXKqV1JdgA: Downloading webpage
# [youtube] 6yXKqV1JdgA: Downloading ios player API JSON
# [youtube] 6yXKqV1JdgA: Downloading tv embedded player API JSON
# [youtube] 6yXKqV1JdgA: Downloading android player API JSON
# [youtube] 6yXKqV1JdgA: Downloading android player API JSON
# [youtube] 6yXKqV1JdgA: Downloading android embedded player API JSON
# [youtube] 6yXKqV1JdgA: Downloading web embedded client config
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (1/3)...
# [youtube] 6yXKqV1JdgA: Downloading player 3ffefd71
# [youtube] 6yXKqV1JdgA: Downloading web embedded player API JSON
# [info] 6yXKqV1JdgA: Downloading subtitles: en
# [info] 6yXKqV1JdgA: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/6yXKqV1JdgA.en.vtt
# [download] Destination: captions/6yXKqV1JdgA.en.vtt
# [download] 100% of  529.04KiB in 00:00:00 at 5.23MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KDCCfyhurXY
# [youtube] KDCCfyhurXY: Downloading webpage
# [youtube] KDCCfyhurXY: Downloading ios player API JSON
# [youtube] KDCCfyhurXY: Downloading android player API JSON
# [youtube] KDCCfyhurXY: Downloading m3u8 information
# [info] KDCCfyhurXY: Downloading subtitles: en
# [info] KDCCfyhurXY: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/KDCCfyhurXY.en.vtt
# [download] Destination: captions/KDCCfyhurXY.en.vtt
# [download] 100% of  608.36KiB in 00:00:00 at 4.94MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=o1Lq5UQkuY4
# [youtube] o1Lq5UQkuY4: Downloading webpage
# [youtube] o1Lq5UQkuY4: Downloading ios player API JSON
# [youtube] o1Lq5UQkuY4: Downloading android player API JSON
# [youtube] o1Lq5UQkuY4: Downloading m3u8 information
# [info] o1Lq5UQkuY4: Downloading subtitles: en
# [info] o1Lq5UQkuY4: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/o1Lq5UQkuY4.en.vtt
# [download] Destination: captions/o1Lq5UQkuY4.en.vtt
# [download] 100% of  600.77KiB in 00:00:00 at 5.79MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Gwmp_-EP75Q
# [youtube] Gwmp_-EP75Q: Downloading webpage
# [youtube] Gwmp_-EP75Q: Downloading ios player API JSON
# [youtube] Gwmp_-EP75Q: Downloading android player API JSON
# [youtube] Gwmp_-EP75Q: Downloading m3u8 information
# [info] Gwmp_-EP75Q: Downloading subtitles: en
# [info] Gwmp_-EP75Q: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/Gwmp_-EP75Q.en.vtt
# [download] Destination: captions/Gwmp_-EP75Q.en.vtt
# [download] 100% of    1.10MiB in 00:00:00 at 4.64MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FKZPLZiBSt8
# [youtube] FKZPLZiBSt8: Downloading webpage
# [youtube] FKZPLZiBSt8: Downloading ios player API JSON
# [youtube] FKZPLZiBSt8: Downloading android player API JSON
# [youtube] FKZPLZiBSt8: Downloading m3u8 information
# [info] FKZPLZiBSt8: Downloading subtitles: en
# [info] FKZPLZiBSt8: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/FKZPLZiBSt8.en.vtt
# [download] Destination: captions/FKZPLZiBSt8.en.vtt
# [download] 100% of  411.58KiB in 00:00:00 at 5.48MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fuPknhfvMAI
# [youtube] fuPknhfvMAI: Downloading webpage
# [youtube] fuPknhfvMAI: Downloading ios player API JSON
# [youtube] fuPknhfvMAI: Downloading android player API JSON
# [youtube] fuPknhfvMAI: Downloading m3u8 information
# [info] fuPknhfvMAI: Downloading subtitles: en
# [info] fuPknhfvMAI: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/fuPknhfvMAI.en.vtt
# [download] Destination: captions/fuPknhfvMAI.en.vtt
# [download] 100% of  993.11KiB in 00:00:00 at 5.94MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MMJw0wE2y7c
# [youtube] MMJw0wE2y7c: Downloading webpage
# [youtube] MMJw0wE2y7c: Downloading ios player API JSON
# [youtube] MMJw0wE2y7c: Downloading android player API JSON
# [youtube] MMJw0wE2y7c: Downloading m3u8 information
# [info] MMJw0wE2y7c: Downloading subtitles: en
# [info] MMJw0wE2y7c: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/MMJw0wE2y7c.en.vtt
# [download] Destination: captions/MMJw0wE2y7c.en.vtt
# [download] 100% of  547.15KiB in 00:00:00 at 5.55MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=M4gJm8fHOvw
# [youtube] M4gJm8fHOvw: Downloading webpage
# [youtube] M4gJm8fHOvw: Downloading ios player API JSON
# [youtube] M4gJm8fHOvw: Downloading android player API JSON
# [youtube] M4gJm8fHOvw: Downloading m3u8 information
# [info] M4gJm8fHOvw: Downloading subtitles: en
# [info] M4gJm8fHOvw: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/M4gJm8fHOvw.en.vtt
# [download] Destination: captions/M4gJm8fHOvw.en.vtt
# [download] 100% of  223.26KiB in 00:00:00 at 4.80MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Uvg32yRi3oM
# [youtube] Uvg32yRi3oM: Downloading webpage
# [youtube] Uvg32yRi3oM: Downloading ios player API JSON
# [youtube] Uvg32yRi3oM: Downloading android player API JSON
# [youtube] Uvg32yRi3oM: Downloading android player API JSON
# [youtube] Uvg32yRi3oM: Downloading player 3ffefd71
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (1/3)...
# [youtube] Uvg32yRi3oM: Downloading m3u8 information
# [info] Uvg32yRi3oM: Downloading subtitles: en
# [info] Uvg32yRi3oM: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/Uvg32yRi3oM.en.vtt
# [download] Destination: captions/Uvg32yRi3oM.en.vtt
# [download] 100% of   62.66KiB in 00:00:00 at 2.23MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 57.66KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 60.02KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 65.20KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 60.99KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 58.22KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (1/3)...
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 54.69KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 58.49KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 59.72KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 52.75KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 60.43KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (1/3)...
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 62.91KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 51.35KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 69.37KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 65.27KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (1/3)...
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (2/3)...
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (3/3)...
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 63.33KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 65.28KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 58.51KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 41.47KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 56.47KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 49.80KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 44.30KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yMWel-ct3nw
# [youtube] yMWel-ct3nw: Downloading webpage
# [youtube] yMWel-ct3nw: Downloading ios player API JSON
# [youtube] yMWel-ct3nw: Downloading tv embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading android player API JSON
# [youtube] yMWel-ct3nw: Downloading android embedded player API JSON
# [youtube] yMWel-ct3nw: Downloading web embedded client config
# [youtube] yMWel-ct3nw: Downloading player 3ffefd71
# [youtube] yMWel-ct3nw: Downloading web embedded player API JSON
# [info] yMWel-ct3nw: Downloading subtitles: en
# [info] yMWel-ct3nw: Downloading 1 format(s): 22
# Deleting existing file captions/yMWel-ct3nw.en.vtt
# [info] Writing video subtitles to: captions/yMWel-ct3nw.en.vtt
# [download] Destination: captions/yMWel-ct3nw.en.vtt
# [download] 100% of    1.41KiB in 00:00:00 at 90.33KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 2.76MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 3.16MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 2.89MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 1.43MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (1/3)...
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 3.24MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (1/3)...
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 3.16MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 3.25MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 3.25MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 2.78MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 2.89MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 3.31MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 2.79MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 2.69MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n2fvtBYv3u0
# [youtube] n2fvtBYv3u0: Downloading webpage
# [youtube] n2fvtBYv3u0: Downloading ios player API JSON
# [youtube] n2fvtBYv3u0: Downloading android player API JSON
# [youtube] n2fvtBYv3u0: Downloading m3u8 information
# [info] n2fvtBYv3u0: Downloading subtitles: en
# [info] n2fvtBYv3u0: Downloading 1 format(s): 22
# Deleting existing file captions/n2fvtBYv3u0.en.vtt
# [info] Writing video subtitles to: captions/n2fvtBYv3u0.en.vtt
# [download] Destination: captions/n2fvtBYv3u0.en.vtt
# [download] 100% of  126.52KiB in 00:00:00 at 3.06MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZoV9UbzTMcg
# [youtube] ZoV9UbzTMcg: Downloading webpage
# [youtube] ZoV9UbzTMcg: Downloading ios player API JSON
# [youtube] ZoV9UbzTMcg: Downloading android player API JSON
# [youtube] ZoV9UbzTMcg: Downloading m3u8 information
# [info] ZoV9UbzTMcg: Downloading subtitles: en
# [info] ZoV9UbzTMcg: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/ZoV9UbzTMcg.en.vtt
# [download] Destination: captions/ZoV9UbzTMcg.en.vtt
# [download] 100% of   29.45KiB in 00:00:00 at 922.65KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZoV9UbzTMcg
# [youtube] ZoV9UbzTMcg: Downloading webpage
# [youtube] ZoV9UbzTMcg: Downloading ios player API JSON
# [youtube] ZoV9UbzTMcg: Downloading android player API JSON
# [youtube] ZoV9UbzTMcg: Downloading m3u8 information
# [info] ZoV9UbzTMcg: Downloading subtitles: en
# [info] ZoV9UbzTMcg: Downloading 1 format(s): 22
# Deleting existing file captions/ZoV9UbzTMcg.en.vtt
# [info] Writing video subtitles to: captions/ZoV9UbzTMcg.en.vtt
# [download] Destination: captions/ZoV9UbzTMcg.en.vtt
# [download] 100% of   29.45KiB in 00:00:00 at 1.06MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZoV9UbzTMcg
# [youtube] ZoV9UbzTMcg: Downloading webpage
# [youtube] ZoV9UbzTMcg: Downloading ios player API JSON
# [youtube] ZoV9UbzTMcg: Downloading android player API JSON
# [youtube] ZoV9UbzTMcg: Downloading m3u8 information
# [info] ZoV9UbzTMcg: Downloading subtitles: en
# [info] ZoV9UbzTMcg: Downloading 1 format(s): 22
# Deleting existing file captions/ZoV9UbzTMcg.en.vtt
# [info] Writing video subtitles to: captions/ZoV9UbzTMcg.en.vtt
# [download] Destination: captions/ZoV9UbzTMcg.en.vtt
# [download] 100% of   29.45KiB in 00:00:00 at 1.06MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZoV9UbzTMcg
# [youtube] ZoV9UbzTMcg: Downloading webpage
# [youtube] ZoV9UbzTMcg: Downloading ios player API JSON
# [youtube] ZoV9UbzTMcg: Downloading android player API JSON
# [youtube] ZoV9UbzTMcg: Downloading m3u8 information
# [info] ZoV9UbzTMcg: Downloading subtitles: en
# [info] ZoV9UbzTMcg: Downloading 1 format(s): 22
# Deleting existing file captions/ZoV9UbzTMcg.en.vtt
# [info] Writing video subtitles to: captions/ZoV9UbzTMcg.en.vtt
# [download] Destination: captions/ZoV9UbzTMcg.en.vtt
# [download] 100% of   29.45KiB in 00:00:00 at 926.16KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZoV9UbzTMcg
# [youtube] ZoV9UbzTMcg: Downloading webpage
# [youtube] ZoV9UbzTMcg: Downloading ios player API JSON
# [youtube] ZoV9UbzTMcg: Downloading android player API JSON
# [youtube] ZoV9UbzTMcg: Downloading m3u8 information
# [info] ZoV9UbzTMcg: Downloading subtitles: en
# [info] ZoV9UbzTMcg: Downloading 1 format(s): 22
# Deleting existing file captions/ZoV9UbzTMcg.en.vtt
# [info] Writing video subtitles to: captions/ZoV9UbzTMcg.en.vtt
# [download] Destination: captions/ZoV9UbzTMcg.en.vtt
# [download] 100% of   29.45KiB in 00:00:00 at 935.03KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZoV9UbzTMcg
# [youtube] ZoV9UbzTMcg: Downloading webpage
# [youtube] ZoV9UbzTMcg: Downloading ios player API JSON
# [youtube] ZoV9UbzTMcg: Downloading android player API JSON
# [youtube] ZoV9UbzTMcg: Downloading m3u8 information
# [info] ZoV9UbzTMcg: Downloading subtitles: en
# [info] ZoV9UbzTMcg: Downloading 1 format(s): 22
# Deleting existing file captions/ZoV9UbzTMcg.en.vtt
# [info] Writing video subtitles to: captions/ZoV9UbzTMcg.en.vtt
# [download] Destination: captions/ZoV9UbzTMcg.en.vtt
# [download] 100% of   29.45KiB in 00:00:00 at 963.28KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZoV9UbzTMcg
# [youtube] ZoV9UbzTMcg: Downloading webpage
# [youtube] ZoV9UbzTMcg: Downloading ios player API JSON
# [youtube] ZoV9UbzTMcg: Downloading android player API JSON
# [youtube] ZoV9UbzTMcg: Downloading m3u8 information
# [info] ZoV9UbzTMcg: Downloading subtitles: en
# [info] ZoV9UbzTMcg: Downloading 1 format(s): 22
# Deleting existing file captions/ZoV9UbzTMcg.en.vtt
# [info] Writing video subtitles to: captions/ZoV9UbzTMcg.en.vtt
# [download] Destination: captions/ZoV9UbzTMcg.en.vtt
# [download] 100% of   29.45KiB in 00:00:00 at 988.33KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZoV9UbzTMcg
# [youtube] ZoV9UbzTMcg: Downloading webpage
# [youtube] ZoV9UbzTMcg: Downloading ios player API JSON
# [youtube] ZoV9UbzTMcg: Downloading android player API JSON
# [youtube] ZoV9UbzTMcg: Downloading m3u8 information
# [info] ZoV9UbzTMcg: Downloading subtitles: en
# [info] ZoV9UbzTMcg: Downloading 1 format(s): 22
# Deleting existing file captions/ZoV9UbzTMcg.en.vtt
# [info] Writing video subtitles to: captions/ZoV9UbzTMcg.en.vtt
# [download] Destination: captions/ZoV9UbzTMcg.en.vtt
# [download] 100% of   29.45KiB in 00:00:00 at 943.73KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZoV9UbzTMcg
# [youtube] ZoV9UbzTMcg: Downloading webpage
# [youtube] ZoV9UbzTMcg: Downloading ios player API JSON
# [youtube] ZoV9UbzTMcg: Downloading android player API JSON
# [youtube] ZoV9UbzTMcg: Downloading m3u8 information
# [info] ZoV9UbzTMcg: Downloading subtitles: en
# [info] ZoV9UbzTMcg: Downloading 1 format(s): 22
# Deleting existing file captions/ZoV9UbzTMcg.en.vtt
# [info] Writing video subtitles to: captions/ZoV9UbzTMcg.en.vtt
# [download] Destination: captions/ZoV9UbzTMcg.en.vtt
# [download] 100% of   29.45KiB in 00:00:00 at 935.42KiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZoV9UbzTMcg
# [youtube] ZoV9UbzTMcg: Downloading webpage
# [youtube] ZoV9UbzTMcg: Downloading ios player API JSON
# [youtube] ZoV9UbzTMcg: Downloading android player API JSON
# [youtube] ZoV9UbzTMcg: Downloading m3u8 information
# [info] ZoV9UbzTMcg: Downloading subtitles: en
# [info] ZoV9UbzTMcg: Downloading 1 format(s): 22
# ...
# [youtube] CzBCVORevQk: Downloading webpage
# [youtube] CzBCVORevQk: Downloading ios player API JSON
# [youtube] CzBCVORevQk: Downloading android player API JSON
# [youtube] CzBCVORevQk: Downloading m3u8 information
# [info] CzBCVORevQk: Downloading subtitles: en
# [info] CzBCVORevQk: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/CzBCVORevQk.en.vtt
# [download] Destination: captions/CzBCVORevQk.en.vtt
# [download] 100% of  149.81KiB in 00:00:00 at 3.52MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cAnG5T7sJeI
# [youtube] cAnG5T7sJeI: Downloading webpage
# [youtube] cAnG5T7sJeI: Downloading ios player API JSON
# [youtube] cAnG5T7sJeI: Downloading android player API JSON
# [youtube] cAnG5T7sJeI: Downloading android player API JSON
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (1/3)...
# [youtube] cAnG5T7sJeI: Downloading m3u8 information
# [info] cAnG5T7sJeI: Downloading subtitles: en
# [info] cAnG5T7sJeI: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/cAnG5T7sJeI.en.vtt
# [download] Destination: captions/cAnG5T7sJeI.en.vtt
# [download] 100% of   36.08KiB in 00:00:00 at 1.55MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=F5ngdgXZpRs
# [youtube] F5ngdgXZpRs: Downloading webpage
# [youtube] F5ngdgXZpRs: Downloading ios player API JSON
# [youtube] F5ngdgXZpRs: Downloading android player API JSON
# [youtube] F5ngdgXZpRs: Downloading m3u8 information
# [info] F5ngdgXZpRs: Downloading subtitles: en
# [info] F5ngdgXZpRs: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/F5ngdgXZpRs.en.vtt
# [download] Destination: captions/F5ngdgXZpRs.en.vtt
# [download] 100% of   91.41KiB in 00:00:00 at 2.79MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_P0oVG5lO-4
# [youtube] _P0oVG5lO-4: Downloading webpage
# [youtube] _P0oVG5lO-4: Downloading ios player API JSON
# [youtube] _P0oVG5lO-4: Downloading android player API JSON
# [youtube] _P0oVG5lO-4: Downloading m3u8 information
# [info] _P0oVG5lO-4: Downloading subtitles: en
# [info] _P0oVG5lO-4: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/_P0oVG5lO-4.en.vtt
# [download] Destination: captions/_P0oVG5lO-4.en.vtt
# [download] 100% of   97.45KiB in 00:00:00 at 3.07MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=R2nwprp1A4Q
# [youtube] R2nwprp1A4Q: Downloading webpage
# [youtube] R2nwprp1A4Q: Downloading ios player API JSON
# [youtube] R2nwprp1A4Q: Downloading android player API JSON
# [youtube] R2nwprp1A4Q: Downloading m3u8 information
# [info] R2nwprp1A4Q: Downloading subtitles: en
# [info] R2nwprp1A4Q: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/R2nwprp1A4Q.en.vtt
# [download] Destination: captions/R2nwprp1A4Q.en.vtt
# [download] 100% of  121.13KiB in 00:00:00 at 3.30MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-lPXeWeN8tg
# [youtube] -lPXeWeN8tg: Downloading webpage
# [youtube] -lPXeWeN8tg: Downloading ios player API JSON
# [youtube] -lPXeWeN8tg: Downloading android player API JSON
# [youtube] -lPXeWeN8tg: Downloading m3u8 information
# [info] -lPXeWeN8tg: Downloading subtitles: en
# [info] -lPXeWeN8tg: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/-lPXeWeN8tg.en.vtt
# [download] Destination: captions/-lPXeWeN8tg.en.vtt
# [download] 100% of  143.71KiB in 00:00:00 at 3.64MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9VTKb1KVK14
# [youtube] 9VTKb1KVK14: Downloading webpage
# [youtube] 9VTKb1KVK14: Downloading ios player API JSON
# [youtube] 9VTKb1KVK14: Downloading android player API JSON
# [youtube] 9VTKb1KVK14: Downloading m3u8 information
# [info] 9VTKb1KVK14: Downloading subtitles: en
# [info] 9VTKb1KVK14: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/9VTKb1KVK14.en.vtt
# [download] Destination: captions/9VTKb1KVK14.en.vtt
# [download] 100% of  159.00KiB in 00:00:00 at 3.03MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OWdulnHTDAo
# [youtube] OWdulnHTDAo: Downloading webpage
# [youtube] OWdulnHTDAo: Downloading ios player API JSON
# [youtube] OWdulnHTDAo: Downloading android player API JSON
# [youtube] OWdulnHTDAo: Downloading m3u8 information
# [info] OWdulnHTDAo: Downloading subtitles: en
# [info] OWdulnHTDAo: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/OWdulnHTDAo.en.vtt
# [download] Destination: captions/OWdulnHTDAo.en.vtt
# [download] 100% of   96.22KiB in 00:00:00 at 2.45MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RW9_4WRxW-c
# [youtube] RW9_4WRxW-c: Downloading webpage
# [youtube] RW9_4WRxW-c: Downloading ios player API JSON
# [youtube] RW9_4WRxW-c: Downloading android player API JSON
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (1/3)...
# [youtube] RW9_4WRxW-c: Downloading android player API JSON
# [youtube] RW9_4WRxW-c: Downloading m3u8 information
# [info] RW9_4WRxW-c: Downloading subtitles: en
# [info] RW9_4WRxW-c: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/RW9_4WRxW-c.en.vtt
# [download] Destination: captions/RW9_4WRxW-c.en.vtt
# [download] 100% of   71.64KiB in 00:00:00 at 2.56MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dPOpJLuZ_FU
# [youtube] dPOpJLuZ_FU: Downloading webpage
# [youtube] dPOpJLuZ_FU: Downloading ios player API JSON
# [youtube] dPOpJLuZ_FU: Downloading android player API JSON
# WARNING: [youtube] YouTube said: ERROR - Precondition check failed.
# WARNING: [youtube] HTTP Error 400: Bad Request. Retrying (1/3)...
# [youtube] dPOpJLuZ_FU: Downloading android player API JSON
# [youtube] dPOpJLuZ_FU: Downloading m3u8 information
# [info] dPOpJLuZ_FU: Downloading subtitles: en
# [info] dPOpJLuZ_FU: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/dPOpJLuZ_FU.en.vtt
# [download] Destination: captions/dPOpJLuZ_FU.en.vtt
# [download] 100% of  106.52KiB in 00:00:00 at 2.95MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=SlKlRYSSjWM
# [youtube] SlKlRYSSjWM: Downloading webpage
# [youtube] SlKlRYSSjWM: Downloading ios player API JSON
# [youtube] SlKlRYSSjWM: Downloading android player API JSON
# [youtube] SlKlRYSSjWM: Downloading m3u8 information
# [info] SlKlRYSSjWM: Downloading subtitles: en
# [info] SlKlRYSSjWM: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/SlKlRYSSjWM.en.vtt
# [download] Destination: captions/SlKlRYSSjWM.en.vtt
# [download] 100% of  120.12KiB in 00:00:00 at 3.26MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=r_whI3vmBFk
# [youtube] r_whI3vmBFk: Downloading webpage
# [youtube] r_whI3vmBFk: Downloading ios player API JSON
# [youtube] r_whI3vmBFk: Downloading android player API JSON
# [youtube] r_whI3vmBFk: Downloading m3u8 information
# [info] r_whI3vmBFk: Downloading subtitles: en
# [info] r_whI3vmBFk: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/r_whI3vmBFk.en.vtt
# [download] Destination: captions/r_whI3vmBFk.en.vtt
# [download] 100% of   76.26KiB in 00:00:00 at 3.01MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=SjWNjwW0rK8
# [youtube] SjWNjwW0rK8: Downloading webpage
# [youtube] SjWNjwW0rK8: Downloading ios player API JSON
# [youtube] SjWNjwW0rK8: Downloading android player API JSON
# [youtube] SjWNjwW0rK8: Downloading m3u8 information
# [info] SjWNjwW0rK8: Downloading subtitles: en
# [info] SjWNjwW0rK8: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/SjWNjwW0rK8.en.vtt
# [download] Destination: captions/SjWNjwW0rK8.en.vtt
# [download] 100% of  168.62KiB in 00:00:00 at 3.86MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bpkQAP568zg
# [youtube] bpkQAP568zg: Downloading webpage
# [youtube] bpkQAP568zg: Downloading ios player API JSON
# [youtube] bpkQAP568zg: Downloading android player API JSON
# [youtube] bpkQAP568zg: Downloading m3u8 information
# [info] bpkQAP568zg: Downloading subtitles: en
# [info] bpkQAP568zg: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/bpkQAP568zg.en.vtt
# [download] Destination: captions/bpkQAP568zg.en.vtt
# [download] 100% of  156.57KiB in 00:00:00 at 3.88MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uDPTIAmT0Ms
# [youtube] uDPTIAmT0Ms: Downloading webpage
# [youtube] uDPTIAmT0Ms: Downloading ios player API JSON
# [youtube] uDPTIAmT0Ms: Downloading android player API JSON
# [youtube] uDPTIAmT0Ms: Downloading m3u8 information
# [info] uDPTIAmT0Ms: Downloading subtitles: en
# [info] uDPTIAmT0Ms: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/uDPTIAmT0Ms.en.vtt
# [download] Destination: captions/uDPTIAmT0Ms.en.vtt
# [download] 100% of   66.93KiB in 00:00:00 at 2.33MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ESXTcsyq8XU
# [youtube] ESXTcsyq8XU: Downloading webpage
# [youtube] ESXTcsyq8XU: Downloading ios player API JSON
# [youtube] ESXTcsyq8XU: Downloading android player API JSON
# [youtube] ESXTcsyq8XU: Downloading m3u8 information
# [info] ESXTcsyq8XU: Downloading subtitles: en
# [info] ESXTcsyq8XU: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/ESXTcsyq8XU.en.vtt
# [download] Destination: captions/ESXTcsyq8XU.en.vtt
# [download] 100% of   44.97KiB in 00:00:00 at 1.71MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2QLcBX_15Ys
# [youtube] 2QLcBX_15Ys: Downloading webpage
# [youtube] 2QLcBX_15Ys: Downloading ios player API JSON
# [youtube] 2QLcBX_15Ys: Downloading android player API JSON
# [youtube] 2QLcBX_15Ys: Downloading m3u8 information
# [info] 2QLcBX_15Ys: Downloading subtitles: en
# [info] 2QLcBX_15Ys: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/2QLcBX_15Ys.en.vtt
# [download] Destination: captions/2QLcBX_15Ys.en.vtt
# [download] 100% of   56.40KiB in 00:00:00 at 2.26MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tdHsQnH9pdU
# [youtube] tdHsQnH9pdU: Downloading webpage
# [youtube] tdHsQnH9pdU: Downloading ios player API JSON
# [youtube] tdHsQnH9pdU: Downloading android player API JSON
# [youtube] tdHsQnH9pdU: Downloading m3u8 information
# [info] tdHsQnH9pdU: Downloading subtitles: en
# [info] tdHsQnH9pdU: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/tdHsQnH9pdU.en.vtt
# [download] Destination: captions/tdHsQnH9pdU.en.vtt
# [download] 100% of  124.26KiB in 00:00:00 at 3.71MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=F72ocefawoc
# [youtube] F72ocefawoc: Downloading webpage
# [youtube] F72ocefawoc: Downloading ios player API JSON
# [youtube] F72ocefawoc: Downloading android player API JSON
# [youtube] F72ocefawoc: Downloading player 3ffefd71
# [youtube] F72ocefawoc: Downloading m3u8 information
# [info] F72ocefawoc: Downloading subtitles: en
# [info] F72ocefawoc: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/F72ocefawoc.en.vtt
# [download] Destination: captions/F72ocefawoc.en.vtt
# [download] 100% of  130.06KiB in 00:00:00 at 3.34MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cJ_uBSNc8qo
# [youtube] cJ_uBSNc8qo: Downloading webpage
# [youtube] cJ_uBSNc8qo: Downloading ios player API JSON
# [youtube] cJ_uBSNc8qo: Downloading android player API JSON
# [youtube] cJ_uBSNc8qo: Downloading m3u8 information
# [info] cJ_uBSNc8qo: Downloading subtitles: en
# [info] cJ_uBSNc8qo: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/cJ_uBSNc8qo.en.vtt
# [download] Destination: captions/cJ_uBSNc8qo.en.vtt
# [download] 100% of  223.28KiB in 00:00:00 at 4.85MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YDleuVh1RDg
# [youtube] YDleuVh1RDg: Downloading webpage
# [youtube] YDleuVh1RDg: Downloading ios player API JSON
# [youtube] YDleuVh1RDg: Downloading android player API JSON
# [youtube] YDleuVh1RDg: Downloading m3u8 information
# [info] YDleuVh1RDg: Downloading subtitles: en
# [info] YDleuVh1RDg: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/YDleuVh1RDg.en.vtt
# [download] Destination: captions/YDleuVh1RDg.en.vtt
# [download] 100% of  311.41KiB in 00:00:00 at 4.74MiB/s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XwCtiVPfjJs
# [youtube] XwCtiVPfjJs: Downloading webpage
# [youtube] XwCtiVPfjJs: Downloading ios player API JSON
# [youtube] XwCtiVPfjJs: Downloading android player API JSON
# [youtube] XwCtiVPfjJs: Downloading m3u8 information
# [info] XwCtiVPfjJs: Downloading subtitles: en
# [info] XwCtiVPfjJs: Downloading 1 format(s): 22
# [info] Writing video subtitles to: captions/XwCtiVPfjJs.en.vtt
# [download] Destination: captions/XwCtiVPfjJs.en.vtt
# [download] 100% of  301.50KiB in 00:00:00 at 4.90MiB/s
# Traceback (most recent call last):
#   File "/var/folders/k3/wh4jzwxx6gq481f_37rdz5bc0000gn/T/ipykernel_24051/376225985.py", line 40, in get_video_captions
#     res = request.execute()
#           ^^^^^^^^^^^^^^^^^
#   File "/Users/weiyue/anaconda3/lib/python3.11/site-packages/googleapiclient/_helpers.py", line 130, in positional_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/weiyue/anaconda3/lib/python3.11/site-packages/googleapiclient/http.py", line 938, in execute
#     raise HttpError(resp, content, uri=self.uri)
# googleapiclient.errors.HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/captions?videoId=Z8DNGhxN9dQ&part=id%2C+snippet&key=AIzaSyA_28SsnEgcSf6wckJM46pR_ZK05A1XzT8&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[112], line 2
#       1 # Get YouTube videos and comments for action videos
# ----> 2 yt_action = get_youtube_data(channel_ids_dict, max_videos, max_comments, action_keywords)
#       3 yt_action["genre"] = "action"
#       4 yt_action.head(3)
#
# Cell In[108], line 16, in get_youtube_data(channel_ids, max_videos, max_comments, keywords)
#      13 logging.info(f"Processing channel: {channel_name}")
#      15 # Get uploads playlist id for channel
# ---> 16 uploads_id = get_uploads_id(channel_id)
#      18 # Get video ids from uploads playlist
#      19 video_ids = get_video_ids(uploads_id, max_videos, keywords)
#
# Cell In[98], line 11, in get_uploads_id(channel_id)
#       5 # Call the API to find uploads channel id
#       6 # Documentation: https://developers.google.com/youtube/v3/docs/channels/list
#       7 request = youtube.channels().list(
#       8     part="contentDetails",
#       9     id=channel_id
#      10 )
# ---> 11 res = request.execute()
#      13 # Extract the uploads playlist id
#      14 uploads_id = res["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
#
# File ~/anaconda3/lib/python3.11/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/channels?part=contentDetails&id=UCAW-NpUFkMyCNrvRSSGIvDQ&key=AIzaSyA_28SsnEgcSf6wckJM46pR_ZK05A1XzT8&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">

# %%
# Check the dimension
yt_action.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 2
#       1 # Check the dimension
# ----> 2 yt_action.shape
#
# NameError: name 'yt_action' is not defined

# %%
# Write to CSV
yt_action.to_csv("../data/yt_action.csv", index=False)

# %% [markdown]
# ### Non-Action Gaming Videos

# %%
# Get YouTube videos and comments for non-action videos
yt_nonaction = get_youtube_data(channel_ids_dict, max_videos, max_comments, nonaction_keywords)
yt_nonaction["genre"] = "non-action"
yt_nonaction.head(3)
# Out:
# Runtime: 812.4069 seconds
#                  channel_id channel_name     video_id  \
# 0  UC-lHJZR3Gqxm24_Vd_AJ5Yw    PewDiePie  KeeeLsAa30M
# 1  UC-lHJZR3Gqxm24_Vd_AJ5Yw    PewDiePie  KeeeLsAa30M
# 2  UC-lHJZR3Gqxm24_Vd_AJ5Yw    PewDiePie  KeeeLsAa30M
#
#                      video_title   video_creation_time  \
# 0  $39,000,000 Minecraft House..  2023-01-17T17:45:00Z
# 1  $39,000,000 Minecraft House..  2023-01-17T17:45:00Z
# 2  $39,000,000 Minecraft House..  2023-01-17T17:45:00Z
#
#                                    video_description  \
# 0  #AD - Pre-Order G FUEL’s New PAC-MAN Flavor! h...
# 1  #AD - Pre-Order G FUEL’s New PAC-MAN Flavor! h...
# 2  #AD - Pre-Order G FUEL’s New PAC-MAN Flavor! h...
#
#                    video_tags video_viewcount video_likecount  \
# 0  [pewdiepie, pewds, pewdie]         3303194          144297
# 1  [pewdiepie, pewds, pewdie]         3303194          144297
# 2  [pewdiepie, pewds, pewdie]         3303194          144297
#
#   video_commentcount                  comment_id         comment_author_id  \
# 0               5115  UgxdYdlUCKKVlFTFRgV4AaABAg  UCepq9z9ovYGxhNrvf6VMSjg
# 1               5115  UgzdaMQoTAzKQHC4_514AaABAg  UChJHWMhmgFg0lYdndo8F9uA
# 2               5115  Ugzeu0RklBcg55PT2nR4AaABAg  UCOC7YrYN12NY-SAtisHge4Q
#
#                                         comment_text          comment_time  \
# 0  Halfway through this recording I had to take a...  2023-01-17T22:07:13Z
# 1  Imagine being the person who invested 39 milli...  2023-01-19T17:12:06Z
# 2  i'll never get tired of Ken and Felix absolute...  2023-01-18T06:03:32Z
#
#    comment_likecount  comment_replycount       genre
# 0               7509                 103  non-action
# 1               1327                  10  non-action
# 2               2333                   3  non-action

# %%
# Check the dimension
yt_nonaction.shape
# Out:
# (76437, 17)

# %%
# Write to CSV
yt_nonaction.to_csv("../data/yt_nonaction.csv", index=False, escapechar="\\")

# %% [markdown]
# ### Complete Dataset

# %%
# Combine into one DataFrame
yt = pd.concat([yt_action, yt_nonaction], ignore_index=True)
yt.head()
# Out:
#                  channel_id channel_name     video_id  \
# 0  UC-lHJZR3Gqxm24_Vd_AJ5Yw    PewDiePie  F-yEoHL7MYY
# 1  UC-lHJZR3Gqxm24_Vd_AJ5Yw    PewDiePie  F-yEoHL7MYY
# 2  UC-lHJZR3Gqxm24_Vd_AJ5Yw    PewDiePie  F-yEoHL7MYY
# 3  UC-lHJZR3Gqxm24_Vd_AJ5Yw    PewDiePie  F-yEoHL7MYY
# 4  UC-lHJZR3Gqxm24_Vd_AJ5Yw    PewDiePie  F-yEoHL7MYY
#
#                                          video_title   video_creation_time  \
# 0  I t̶r̶i̶e̶d̶ ̶t̶o̶ beat Elden Ring Without Dyi...  2022-04-30T16:40:18Z
# 1  I t̶r̶i̶e̶d̶ ̶t̶o̶ beat Elden Ring Without Dyi...  2022-04-30T16:40:18Z
# 2  I t̶r̶i̶e̶d̶ ̶t̶o̶ beat Elden Ring Without Dyi...  2022-04-30T16:40:18Z
# 3  I t̶r̶i̶e̶d̶ ̶t̶o̶ beat Elden Ring Without Dyi...  2022-04-30T16:40:18Z
# 4  I t̶r̶i̶e̶d̶ ̶t̶o̶ beat Elden Ring Without Dyi...  2022-04-30T16:40:18Z
#
#                                    video_description  \
# 0  🌏 Get exclusive NordVPN deal here ➵  https://N...
# 1  🌏 Get exclusive NordVPN deal here ➵  https://N...
# 2  🌏 Get exclusive NordVPN deal here ➵  https://N...
# 3  🌏 Get exclusive NordVPN deal here ➵  https://N...
# 4  🌏 Get exclusive NordVPN deal here ➵  https://N...
#
#                    video_tags video_viewcount video_likecount  \
# 0  [pewdiepie, pewds, pewdie]        11540558          473052
# 1  [pewdiepie, pewds, pewdie]        11540558          473052
# 2  [pewdiepie, pewds, pewdie]        11540558          473052
# 3  [pewdiepie, pewds, pewdie]        11540558          473052
# 4  [pewdiepie, pewds, pewdie]        11540558          473052
#
#   video_commentcount                  comment_id         comment_author_id  \
# 0              15129  UgwN1kGXwi9M7jeOb0d4AaABAg  UCLHsZ4X7YemjxRrvq0AI4LA
# 1              15129  UgwW5nWEkxdES-g3hk54AaABAg  UCJ9VDCLZDmeJIU3Branlstg
# 2              15129  UgyGe0HN8toQWUZZtCl4AaABAg  UCs-mo1206PASdacjDqfdLng
# 3              15129  UgynWxW3iPqZkLh107F4AaABAg  UCZbZYh7zCRnS1agWpUkOogw
# 4              15129  Ugw8ym0lRIWdoz5m8q14AaABAg  UCx2sOV-ra7OD75snrhwOWxA
#
#                                         comment_text          comment_time  \
# 0  Damn dude, even with mimic I think it would ta...  2022-05-02T19:37:22Z
# 1  This is the pewds that I thought he’d turn int...  2022-12-14T23:36:11Z
# 2  This is actually awesome. Can't believe a meme...  2022-12-31T18:16:36Z
# 3  Wow, didn't even know Pewds had this analytica...  2023-01-19T18:49:19Z
# 4  Damn, i cant believe it took me 11 months afte...  2023-04-21T17:00:36Z
#
#    comment_likecount  comment_replycount   genre
# 0               9818                  47  action
# 1               6251                   9  action
# 2               5041                  54  action
# 3               1323                   2  action
# 4                483                   3  action

# %%
# Check the dimension
yt.shape

# %%
# Write to CSV
yt.to_csv("../data/yt.csv", index=False, escapechar="\\")
