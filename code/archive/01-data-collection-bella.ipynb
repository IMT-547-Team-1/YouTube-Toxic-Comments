# %% [markdown]
# ## Project Phase 1: Data Collection

# %% [markdown]
# #### Title: YouTube Gaming Comments Toxicity
# #### Team name:
# #### Team members: Chesie Yu, Hongfan Lu, Bella Wei
# #### Problem Description: Toxicity in the gaming community is a prevalent problem that hinders the harmonious development of the gaming industry. Our objective is to tackle this concern by exploring whether the game category (Action and Non-Action) serves as a primary determinant of toxicity levels in YouTube video comments. This study focuses on the observational perspective rather than the player angle. If proven, it can offer valuable insights for gaming community management, game design, and the design of social media platforms.

# %% [markdown]
# #### RQ1: Do videos of action games arouse significant more toxic comments than non-action games in YouTube?

# %% [markdown]
# #### RQ2: Which kinds of gaming video attract most toxic comments? Any pattern behind the scene?

# %% [markdown]
# ### Data collection steps:
# #### 1. Utilizing YouTube API to access Youtube comments
# #### 2. Selecting [] as keywords for ActionGames, and [] as keywords for NonActionGames.
# #### 3. Collecting Top 2000 Most Relevant Videos in each category
# #### 4. Random Sampling to pick 200 videos each
# #### 5. Saving comments in these 200 videos into seperated csv.

# %%
# API_KEY = "AIzaSyA_28SsnEgcSf6wckJM46pR_ZK05A1XzT8"
# API_KEY = "AIzaSyBaSTAz4h-ed9eH0WL0P_UqPl0NNodfMOg"
# API_KEY = "AIzaSyCPo6cHarTXbYaov23Q-pqtYnb6FXJo7L8"
API_KEY = "AIzaSyCsXkbTw06trv3ll4KhkB4wtvLlAW6EKGc"

# %%
# !pip install --upgrade google-api-python-client --quiet

# %%
import json

import googleapiclient
import googleapiclient.discovery
import googleapiclient.errors
import pandas as pd

# %%
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=API_KEY)

# %%
youtube

# %%
channel_name_list=['FaZe Rug', 'Ninja', 'DUDU e CAROL','Jelly','invictor',
'SSundee','FGTeeV','IShowSpeed','Minecraft - Topic','LazarBeam']

# %%
ActionGame_keyword_list = ['Call of Duty','GTA','The Last of Us','God of War','Batman','Red Dead Redemption',
                           "Assassin's Creed",'Star Wars Jedi','Resident Evil','Cyberpunk','Fallout','Tomb Raider','Elden Ring']

# %%
for username in channel_name_list:
    request = youtube.channels().list(
        part="contentDetails",
        forUsername=username
    )
    keyword_res = request.execute()
    print(json.dumps(keyword_res,indent=2))
    break
# Out:
# {
#   "kind": "youtube#channelListResponse",
#   "etag": "RuuXzTIr0OoDqI4S0RU6n4FqKEM",
#   "pageInfo": {
#     "totalResults": 0,
#     "resultsPerPage": 5
#   }
# }

# %%
import nltk
from nltk.stem import PorterStemmer
# Initialize NLTK
nltk.download("punkt")
porter = PorterStemmer()
import re
# Out:
# [nltk_data] Downloading package punkt to /Users/weiyue/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def search_keyword_videos(keyword_list, channel_name):
    relevant_videos = []
    next_page_token = None
    while len(relevant_videos) < 50:
        request = youtube.search().list(
            part='snippet, id',
            q= channel_name,
            maxResults=50,
            pageToken=next_page_token,
            order='date'
        )
        response = request.execute()
        stemmed_keywords = set(porter.stem(keyword) for keyword in keyword_list)

        for item in response.get('items', []):
            video_title = item['snippet']['title'].lower()
            if any(re.search(r'\b{}\b'.format(re.escape(porter.stem(keyword))), video_title) for keyword in stemmed_keywords):
                video_id = item['id']['videoId']
                # this is for viewCount
                view_count = youtube.videos().list(
                id = video_id,
                part = 'statistics'
                ).execute()

                video_info = {
                    'Channel Name': channel_name,
                    'Video ID':video_id,
                    'Video title': item['snippet']['title'],
                    'Video creation time': item['snippet']['publishedAt'],
                    #'Video number of views': view_count['items'][0]['statistics']['viewCount']
                }
                relevant_videos.append(video_info)
            if len(relevant_videos) >= 50:
                break
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

    print(f"Found {len(relevant_videos)} keyword-related videos from {channel_name}.")
    return relevant_videos

# %%
relevant_videos
# Out:
# {'FaZe Rug': [],
#  'Ninja': [{'Channel Name': 'Ninja',
#    'Video ID': 'VeyvUwnK_SM',
#    'Video title': '#automobile #gta #ninja #gaming #games ninja h2 top speed new tranding#rider',
#    'Video creation time': '2024-02-17T01:49:25Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'zGOn_qhZlBo',
#    'Video title': 'From Sonic To NINJA SONIC In GTA 5!',
#    'Video creation time': '2023-04-04T16:44:13Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'FDaZssDxWMo',
#    'Video title': 'Animated Ninja Superbike Vs. 7 Fast POLICE Cars!! *INTENSE* | GTA 5',
#    'Video creation time': '2022-08-01T11:05:07Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'J4eFe_bTM7Y',
#    'Video title': 'Ninja SUPERBIKE vs Drag BIKE sa GTA 5! (TOP SPEED)',
#    'Video creation time': '2021-09-05T06:07:44Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'UgS0juE-l5w',
#    'Video title': 'Ninja Kidz Team Up With Batman and Robin Movie Remastered!',
#    'Video creation time': '2021-08-28T12:15:01Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'JjsFKksNusc',
#    'Video title': 'Ninja Kidz &amp; Batman team-up to Save Robin from the Joker!',
#    'Video creation time': '2020-11-14T13:15:01Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': '9F-HAcmVIyQ',
#    'Video title': 'Ninja Kidz team up with Robin to Save Batman from The Joker!',
#    'Video creation time': '2020-03-28T12:00:09Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'vWzkzjGOPaU',
#    'Video title': 'Turtles vs Batman | Batman vs Teenage Mutant Ninja Turtles',
#    'Video creation time': '2019-12-01T02:45:26Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'jZ3ur_mZAaM',
#    'Video title': 'Batman vs. Teenage Mutant Ninja Turtles',
#    'Video creation time': '2019-03-28T04:00:15Z'}]}

# %%
print(channel_name_list)
relevant_videos.keys()
# Out:
# ['FaZe Rug', 'Ninja', 'DUDU e CAROL', 'Jelly', 'invictor', 'SSundee', 'FGTeeV', 'IShowSpeed', 'Minecraft - Topic', 'LazarBeam']
# dict_keys(['FaZe Rug', 'Ninja', 'DUDU e CAROL', 'Jelly', 'invictor', 'SSundee', 'FGTeeV', 'IShowSpeed', 'Minecraft - Topic', 'LazarBeam'])

# %%
for username in channel_name_list:
    if username not in relevant_videos:
        relevant_videos[username]=search_keyword_videos(ActionGame_keyword_list, username)
# Out:
# Found 1 keyword-related videos from IShowSpeed.
# Found 0 keyword-related videos from Minecraft - Topic.
# Found 11 keyword-related videos from LazarBeam.

# %%
relevant_videos
# Out:
# {'FaZe Rug': [],
#  'Ninja': [{'Channel Name': 'Ninja',
#    'Video ID': 'VeyvUwnK_SM',
#    'Video title': '#automobile #gta #ninja #gaming #games ninja h2 top speed new tranding#rider',
#    'Video creation time': '2024-02-17T01:49:25Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'zGOn_qhZlBo',
#    'Video title': 'From Sonic To NINJA SONIC In GTA 5!',
#    'Video creation time': '2023-04-04T16:44:13Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'FDaZssDxWMo',
#    'Video title': 'Animated Ninja Superbike Vs. 7 Fast POLICE Cars!! *INTENSE* | GTA 5',
#    'Video creation time': '2022-08-01T11:05:07Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'J4eFe_bTM7Y',
#    'Video title': 'Ninja SUPERBIKE vs Drag BIKE sa GTA 5! (TOP SPEED)',
#    'Video creation time': '2021-09-05T06:07:44Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'UgS0juE-l5w',
#    'Video title': 'Ninja Kidz Team Up With Batman and Robin Movie Remastered!',
#    'Video creation time': '2021-08-28T12:15:01Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'JjsFKksNusc',
#    'Video title': 'Ninja Kidz &amp; Batman team-up to Save Robin from the Joker!',
#    'Video creation time': '2020-11-14T13:15:01Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': '9F-HAcmVIyQ',
#    'Video title': 'Ninja Kidz team up with Robin to Save Batman from The Joker!',
#    'Video creation time': '2020-03-28T12:00:09Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'vWzkzjGOPaU',
#    'Video title': 'Turtles vs Batman | Batman vs Teenage Mutant Ninja Turtles',
#    'Video creation time': '2019-12-01T02:45:26Z'},
#   {'Channel Name': 'Ninja',
#    'Video ID': 'jZ3ur_mZAaM',
#    'Video title': 'Batman vs. Teenage Mutant Ninja Turtles',
#    'Video creation time': '2019-03-28T04:00:15Z'}],
#  'DUDU e CAROL': [{'Channel Name': 'DUDU e CAROL',
#    'Video ID': '6dgeNwb_yrU',
#    'Video title': 'NAMORADA na AUTO ESCOLA de CAMINHÃO no GTA 5',
#    'Video creation time': '2018-04-20T23:30:00Z'}],
#  'Jelly': [{'Channel Name': 'Jelly',
#    'Video ID': 'tZy7_rrFGOw',
#    'Video title': 'Hiding As A FIRE HYDRANT In GTA 5 PROP HUNT!',
#    'Video creation time': '2024-01-08T17:14:53Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': '52_IaR-PvM4',
#    'Video title': 'Prop Hunt + GTA 5 = HILARIOUS! (Garry’s Mod)',
#    'Video creation time': '2023-12-18T17:22:01Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': '9YajNemNtfI',
#    'Video title': 'Touch The PLATFORM To WIN! (*NEW* GTA 5 Game Mode)',
#    'Video creation time': '2023-10-17T15:57:14Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'UzjG6XLO3gk',
#    'Video title': 'Playing BALLOON TAG In GTA 5...',
#    'Video creation time': '2023-10-12T15:28:34Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'Oqh9ZxHb-6w',
#    'Video title': 'Wrong Color = ELIMINATED! (GTA 5 Color Switch)',
#    'Video creation time': '2023-10-07T16:35:01Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'cJ3yuNyzBNE',
#    'Video title': 'Timer Gap vs. SUPERCAR! (GTA 5)',
#    'Video creation time': '2023-09-23T15:15:02Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': '3vgOCYqNHTs',
#    'Video title': 'Don&#39;t Get CRUSHED In This GTA 5 Race...',
#    'Video creation time': '2023-09-16T15:45:00Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': '2AZje-qsEdc',
#    'Video title': 'Tank vs. 100 People… (GTA 5)',
#    'Video creation time': '2023-09-13T15:00:01Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'fgpOh7ScYo0',
#    'Video title': 'Can I Outrun A BOMB In GTA 5…',
#    'Video creation time': '2023-09-08T15:15:01Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': '4rNSnLvIeN8',
#    'Video title': 'Don’t Leave The Circle In GTA 5…',
#    'Video creation time': '2023-09-06T15:06:35Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'U_YhI6Hgloo',
#    'Video title': 'Sumo On A RUBIX CUBE In GTA 5!',
#    'Video creation time': '2023-09-01T20:37:24Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': '5yGOoS4ehiU',
#    'Video title': 'Attempting Impossible GTA 5 Trickshots!',
#    'Video creation time': '2023-08-25T18:00:02Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': '-yHTnd-Ia-U',
#    'Video title': '*NEW* $7,500,000 FIGHTER JET In GTA 5! (DLC)',
#    'Video creation time': '2023-06-14T16:16:38Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': '-yHTnd-Ia-U',
#    'Video title': '*NEW* $7,500,000 FIGHTER JET In GTA 5! (DLC)',
#    'Video creation time': '2023-06-14T16:16:38Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'sI8az0eaKg8',
#    'Video title': 'Face To Face On A TIGHTROPE! (GTA 5)',
#    'Video creation time': '2023-06-12T18:01:52Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': '3ZstqaftXk4',
#    'Video title': 'The BEST CHEAT to BEAT JELLY in a 1v1 Race (GTA 5)',
#    'Video creation time': '2023-04-26T16:00:08Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'Qe_kmfGxX7I',
#    'Video title': 'Face To Face On A COLLAPSING BRIDGE... (GTA 5)',
#    'Video creation time': '2023-04-09T15:01:08Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'DImWGnOWPSg',
#    'Video title': '1v1 Race But I CHEAT To Beat Jelly! (GTA 5)',
#    'Video creation time': '2023-04-08T16:00:10Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'haDgcR-5V1E',
#    'Video title': '2 NOOBS vs. Sabotager INSURGENT! (GTA 5)',
#    'Video creation time': '2023-03-23T18:15:25Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'J9DKCfRGkj8',
#    'Video title': 'GTA 5 1v1 Race vs Jelly and Sabotager!',
#    'Video creation time': '2023-03-15T17:00:18Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'zxqTsV6isGM',
#    'Video title': 'Extreme SABOTAGER In GTA 5 Face To Face...',
#    'Video creation time': '2023-03-09T21:44:10Z'},
#   {'Channel Name': 'Jelly',
#    'Video ID': 'ALEhVBX98TQ',
#    'Video title': 'Playing GTA 5 As A BILLIONAIRE!',
#    'Video creation time': '2019-08-14T19:24:56Z'}],
#  'invictor': [{'Channel Name': 'invictor',
#    'Video ID': 'eiTQvD0PUWY',
#    'Video title': 'LAS CAJAS MISTERIOSAS en GTA 5 😱 ¿QUÉ CONSEGUIRÉ? 🤣 LOS COMPAS',
#    'Video creation time': '2024-02-13T23:27:40Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '4McQ8k6v6Cg',
#    'Video title': 'GTA 5 ¡IMPOSIBLE SOBREVIVIR a la AVALANCHA de SUPER AUTOS! 😨💥 Los COMPAS Final',
#    'Video creation time': '2024-02-08T22:45:00Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '0V3L_TPovK4',
#    'Video title': 'NO ELIJAS el CARRO EQUIVOCADO en GTA 5 🤣 COCHE de 1$ vs COCHE de 10.000.000$ 💸',
#    'Video creation time': '2024-02-07T20:26:28Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'KM9_mQH5JS4',
#    'Video title': 'RETO IMPOSIBLE: SOBREVIVE a la MEGA RAMPA DE HIELO en GTA 5 😂🥶',
#    'Video creation time': '2024-01-05T18:30:33Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'NUDiEb95C_U',
#    'Video title': 'INVICTOR vs TREN en GTA 5 😱 ME DESTROZAN EL COCHE en este CARA A CARA',
#    'Video creation time': '2023-12-07T22:23:19Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'cQjWBvl5aH0',
#    'Video title': '¡LA MEGA RAMPA MÁS PELIGROSA de GTA 5! 😱 INVICTOR',
#    'Video creation time': '2023-11-11T01:19:27Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'vbnxfPiaLE8',
#    'Video title': '¡IMPOSIBLE SOBREVIVIR al TREN en GTA 5! 🚂😱',
#    'Video creation time': '2023-11-05T23:19:05Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '21-N8SZ0iGA',
#    'Video title': '¡RULETA de CAJAS MISTERIOSAS en GTA 5! 🤣 ¿QUÉ ARMA CONSEGUIRÉ? INVICTOR',
#    'Video creation time': '2023-10-20T21:09:10Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'bR5stpYb-e0',
#    'Video title': 'RETO del PARKOUR de LOOPING 99.8% IMPOSSIBLE en GTA 5 😱 INVICTOR',
#    'Video creation time': '2023-10-13T00:52:05Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'RBFN5FDsX7c',
#    'Video title': 'PARKOUR EXTREMO pero ESTAMOS UNIDOS ⛓️🤣 ¿Sobreviviremos? GTA 5 INVICTOR',
#    'Video creation time': '2023-09-29T23:27:42Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'jxIE8KxHs64',
#    'Video title': 'Imposible MEGA RAMPA 100% VERTICAL en GTA 5 😱',
#    'Video creation time': '2023-09-22T18:30:40Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'FaIVu1VeoJ4',
#    'Video title': '99.8% IMPOSIBLE TERMINAR este LABERINTO en GTA 5 🏎️😱 INVICTOR',
#    'Video creation time': '2023-09-15T22:34:58Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'zMlaUrZSoVY',
#    'Video title': '¿Puedes SALTAR 100 CAMIONES con una MEGA RAMPA en GTA 5?',
#    'Video creation time': '2023-09-04T22:32:00Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'W6wE7IgZnW0',
#    'Video title': 'MINI CARRO vs DESTRUCTOR DE AUTOS  en GTA 5 😱 INVICTOR',
#    'Video creation time': '2023-08-22T19:50:46Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '_WDDLl7A7oM',
#    'Video title': '¿Puedes pasar el PARKOUR MÁS PELIGROSO de GTA 5? 😱🥵 Invictor',
#    'Video creation time': '2023-06-29T19:00:13Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'mxpv74dws0Y',
#    'Video title': 'LOS COMPAS vs LA TRITURADORA DE AUTOS en GTA 5 😱😨 CARA A CARA INVICTOR',
#    'Video creation time': '2023-06-10T00:04:06Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'JrANiLOpTzs',
#    'Video title': 'TANQUE 99% ILEGAL vs CARRO EXCAVADORA 😂 CARA a CARA con COCHES MOD en GTA 5',
#    'Video creation time': '2023-05-10T23:59:28Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'B9ZwFTAs84Q',
#    'Video title': '¡No escojas el CAMINO EQUIVOCADO en GTA 5 (CARA A CARA) 😱 INVICTOR y LOS COMPAS',
#    'Video creation time': '2023-02-03T01:07:16Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'yg5BeoJOWHs',
#    'Video title': 'NADIE SOBREVIVE A ESTE CARA A CARA EN GTA 5 😱 Los COMPAS TIMBA INVICTOR RIUS y MONDONGO',
#    'Video creation time': '2022-12-15T22:45:05Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'wLfcp0a5jnc',
#    'Video title': '¡EL COCHE MÁS LARGO DE GTA 5 (+100 metros) vs LOS COMPAS! 😱 CARA A CARA INVICTOR',
#    'Video creation time': '2022-10-27T18:53:57Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'wLfcp0a5jnc',
#    'Video title': '¡EL COCHE MÁS LARGO DE GTA 5 (+100 metros) vs LOS COMPAS! 😱 CARA A CARA INVICTOR',
#    'Video creation time': '2022-10-27T18:53:57Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'fN1Mlqiq7e0',
#    'Video title': '¡Nos CONVERTIMOS en ANIMALES en GTA 5! 🐘😂 LOS COMPAS vs PARKOUR 99% IMPOSIBLE',
#    'Video creation time': '2022-06-14T23:39:26Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'DtSrZsW41wo',
#    'Video title': '¡BICICLETA vs HELICOPTEROS ASESINOS en GTA 5! 🚁😱 ¿SOBREVIVIRÁ INVICTOR?',
#    'Video creation time': '2022-05-20T23:38:57Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'd4fkyeDaweo',
#    'Video title': '¡NADIE SOBREVIVE a la MEGA RAMPA ESPIRAL en GTA 5! 🚗😱 LOS COMPAS',
#    'Video creation time': '2022-04-27T22:18:00Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'y1nn4olXRJ4',
#    'Video title': '¡INVICTOR vs TANQUES BLINDADOS en GTA 5! 😂🚓',
#    'Video creation time': '2022-03-22T00:25:41Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'HwnB3I5E50Y',
#    'Video title': '¡NO ELIJAS el CAMINO INCORRECTO en esta CARRERA IMPOSIBLE! 😂 CARA a CARA en GTA 5 😱 INVICTOR',
#    'Video creation time': '2022-03-10T01:39:15Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '2DGEx9L3MYU',
#    'Video title': '¡Sólo el 0.1% SUPERA la MEGA RAMPA INFINITA! 😱🏎️ INVICTOR en CARA A CARA GTA 5',
#    'Video creation time': '2022-01-28T23:48:19Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '5IVFxilUloQ',
#    'Video title': '¡Nadie SOBREVIVE al TOBOGÁN ESPIRAL en GTA 5! 😂 INVICTOR vs los COMPAS en la CARRERA IMPOSIBLE',
#    'Video creation time': '2022-01-09T01:52:34Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'MHE9OxwFItg',
#    'Video title': 'INVICTOR vs SUPER COCHES con TURBO 😂 NADIE PUEDE TIRAR A LOS COMPAS en GTA 5',
#    'Video creation time': '2021-11-30T22:22:17Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'xywMpnddSoE',
#    'Video title': '¡¡NO TE CAIGAS en la TRITURADORA de AUTOS!! 😱⚠ RETO IMPOSIBLE de INVICTOR en GTA 5',
#    'Video creation time': '2021-11-25T01:59:50Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'UtPpQ-sD-dM',
#    'Video title': '¡GTA 5 pero los SALTOS son 99% IMPOSIBLES! 😂 ¿CHOCAREMOS? 🤯 INVICTOR SALTOS de PRECISIÓN',
#    'Video creation time': '2021-11-07T23:39:34Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'a-r4KUPetrk',
#    'Video title': '¡COCHE MÁS LARGO vs TANQUE BLINDADO! 😂😱 ¿QUIÉN GANARÁ ESTA CARRERA entre COMPAS? 😂 GTA 5',
#    'Video creation time': '2021-10-07T00:02:32Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'TwvCts1uxkc',
#    'Video title': '1000% IMPOSIBLE: RETO de FUEGO Y HIELO! 🔥❄ INVICTOR GTA 5',
#    'Video creation time': '2021-09-26T00:57:08Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'CmZWt9OlbjE',
#    'Video title': 'GTA 5 pero NOS CONVERTIMOS en MONSTER TRUCK!! 😱🏆 TROLLINO vs MIKECRACK vs INVICTOR vs TIMBAVK',
#    'Video creation time': '2021-09-19T19:30:12Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '155xXdFnSC8',
#    'Video title': '¡SOBREVIVE a LOS COCHES DESTRUCTURES en GTA 5! 😂🚓 INVICTOR',
#    'Video creation time': '2021-09-10T00:52:26Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'yIcjFmaTB7Y',
#    'Video title': 'VUELCA COCHES vs TREN en GTA 5!! 😱🚆 INVICTOR vs LOS COMPAS (Cara a cara)',
#    'Video creation time': '2021-08-28T19:29:38Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'r0n1D6sndb0',
#    'Video title': '¡GTA 5 pero LA CARRERA ES 99.9% IMPOSIBLE! 😂😨 INVICTOR Y LOS COMPAS',
#    'Video creation time': '2021-08-17T20:11:41Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'hnMy0D4rL88',
#    'Video title': '¡LOS COMPAS CHOCAMOS en SUPER MOTOS! 😂😱 INVICTOR en GTA 5 TRON #1',
#    'Video creation time': '2021-08-03T01:34:13Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'cNTkwgIG2lY',
#    'Video title': 'INVICTOR vs PARKOUR EXTREMO de TIBURONES 🦈😱 ¡IMPOSIBLE SOBREVIVIR A ESTA CARRERA en GTA 5!',
#    'Video creation time': '2021-07-08T21:26:44Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '3-DRFYxcb-M',
#    'Video title': '¡NADIE PUEDE TIRAR a INVICTOR en GTA 5! 😂😱 AUTOS vs CORREDORES 😱 RAGDOLL GTA V',
#    'Video creation time': '2021-06-30T00:47:01Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'fTugoGZRZJg',
#    'Video title': '¡INVICTOR vs LA CARRERA 100% IMPOSIBLE de GTA 5! 😱😂 Los COMPAS CHOCAMOS en SUPER AUTOS',
#    'Video creation time': '2021-06-23T18:42:32Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'R4KmVjLnGQQ',
#    'Video title': 'GTA 5 pero HAY TIBURONES 😱 ELTROLLINO y MIKECRACK vs INVICTOR y TIMBAVK en CAPTURA LA BANDERA',
#    'Video creation time': '2021-06-19T18:20:12Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'Ftoge7S0NPU',
#    'Video title': '¡INVICTOR vs LA RULETA ARCOIRIS IMPOSIBLE! 😂🔴 LOS COMPAS en EL PARKOUR 99.2% IMPOSIBLE en GTA 5',
#    'Video creation time': '2021-06-03T20:30:08Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'i06zBs7MHaQ',
#    'Video title': 'GTA 5 pero LOS COMPAS se DESTRUYEN en SUPER AUTOS 😱 TROLLINO, MIKECRACK, INVICTOR Y RAPTORGAMER',
#    'Video creation time': '2021-06-02T23:21:00Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'BP9lVrI70EY',
#    'Video title': '¡LOS COMPAS vs PARKOUR MÁS TROLL! 😂🔴 INVICTOR en LA CARRERA 100% IMPOSIBLE en GTA 5',
#    'Video creation time': '2021-05-24T20:49:47Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '1M-usGOto1E',
#    'Video title': '¡NADIE SOBREVIVE al TREN de GTA 5! 🚆😂 INVICTOR Y LOS COMPAS CHOCAN con AUTOS',
#    'Video creation time': '2021-05-22T00:40:56Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '38rJKeT4y2M',
#    'Video title': '1000% IMPOSIBLE: PARKOUR EXTREMO EN GTA 5 ONLINE 😱😂 INVICTOR, ACENIX y ELMAYO97',
#    'Video creation time': '2021-05-21T20:40:29Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': 'k3g0GGDlHUY',
#    'Video title': 'GTA 5 ¡LA CARRERA de LA MUERTE! 💀😱 GTA V con INVICTOR, ACENIX y MIKECRACK',
#    'Video creation time': '2021-05-15T00:48:32Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '8sUTH24TmY0',
#    'Video title': '¡COCHE RAMPA vs TANQUE BLINDADO! 😱💥 GTA 5 CARA A CARA con INVICTOR',
#    'Video creation time': '2021-05-13T23:12:43Z'},
#   {'Channel Name': 'invictor',
#    'Video ID': '6fXk8blrnCc',
#    'Video title': 'DESTRUCTOR de AUTOS vs MEGA RAMPA 99% IMPOSIBLE 😂 LOS COMPAS en GTA 5 (Cara a cara)',
#    'Video creation time': '2021-04-26T22:23:26Z'}]}

# %%
# from urllib2 import HTTPError
def extract_100_comments(video_id_list):
    comments_per_video = []
    for vid in video_id_list:
        try:
            request = youtube.commentThreads().list(
                videoId = vid,
                part = "id,snippet,replies",
                textFormat = "plainText",
                order = "time",
                maxResults = 100
            )
            response = request.execute()

            for item in response["items"]:
                comments = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                has_reply = item["snippet"]["totalReplyCount"]
                if has_reply != 0:
                    replies = []
                    for i in range(len(item["replies"]["comments"])):
                        reply = item["replies"]["comments"][i]['snippet']["textDisplay"]
                        replies.append(reply)
                else:
                    replies = None
                comment_info = {
                    'Video ID': vid,
                    'Comment id': item['snippet']['topLevelComment']['id'],
                    'Comment title': item['snippet']['topLevelComment']['snippet']['textOriginal'],
                    'Comment creation time': item['snippet']['topLevelComment']['snippet']['publishedAt'],
                    'Comment number of likes': item['snippet']['topLevelComment']['snippet']['likeCount'],
                    'Comment content': comments,
                    'Replies': replies
                }
                comments_per_video.append(comment_info)
#         except HTTPError as e:
        except:
            continue
#             if e.resp.status == 403:
#                 print(f"Comments are disabled for video with ID: {vid}")
#                 comments_per_video.append(f"Comments are disabled for video with ID: {vid}")
#             else:
# #                 raise e  # Re-raise the exception if it's not a 403 error
#                 continue
    return comments_per_video

# %%
video_comments = {}

# %%
video_comments.keys()
# Out:
# dict_keys(['FaZe Rug', 'Ninja', 'DUDU e CAROL', 'Jelly', 'invictor', 'SSundee', 'FGTeeV', 'IShowSpeed', 'Minecraft - Topic', 'LazarBeam'])

# %%
for channel_name in relevant_videos:
    if channel_name in video_comments:
        continue
    item_video_ids = [d['Video ID'] for d in relevant_videos[channel_name] if 'Video ID' in d]
    channel_video_comments = extract_100_comments(item_video_ids)
    video_comments[channel_name] = channel_video_comments

# %%
json.dump(video_comments, open("channel_video_comments.json", "w"), indent=2)
